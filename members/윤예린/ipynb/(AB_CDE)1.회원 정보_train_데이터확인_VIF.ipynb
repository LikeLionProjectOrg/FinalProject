# %%
# 기본
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 경고 뜨지 않게 설정
import warnings
warnings.filterwarnings('ignore')

# 그래프 설정
sns.set()

# 그래프 기본 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
# plt.rcParams['font.family'] = 'AppleGothic'
plt.rcParams['figure.figsize'] = 12, 6
plt.rcParams['font.size'] = 14
plt.rcParams['axes.unicode_minus'] = False

# 데이터 전처리 알고리즘
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

# 학습용과 검증용으로 나누는 함수
from sklearn.model_selection import train_test_split

# 교차 검증
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold

# 평가함수
# 분류용
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score

# 회귀용
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# 모델의 최적의 하이퍼 파라미터를 찾기 위한 도구
from sklearn.model_selection import GridSearchCV

# 머신러닝 알고리즘 - 분류
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import VotingClassifier

# 머신러닝 알고리즘 - 회귀
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
from sklearn.ensemble import VotingRegressor

# 차원 축소
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# 군집
from sklearn.cluster import KMeans
from sklearn.cluster import MeanShift
from sklearn.cluster import estimate_bandwidth

# 학습 모델 저장을 위한 라이브러리
import pickle

# %%
import pandas as pd
import glob

# %%
# 1. 모든 parquet 파일 경로 가져오기
file_list = glob.glob('open/train/1.회원정보/2018*_train_회원정보.parquet')

# 2. 데이터프레임 리스트 생성
df_list = [pd.read_parquet(f) for f in file_list]

# 3. 하나로 합치기
all_df = pd.concat(df_list, ignore_index=True)

# 4. 확인
print(all_df.shape)
all_df.head(10)
# Out:
# (2400000, 78)
#      기준년월            ID  남녀구분코드   연령 Segment  회원여부_이용가능  회원여부_이용가능_CA  \
# 0  201807  TRAIN_000000       2  40대       D          1             1
# 1  201807  TRAIN_000001       1  30대       E          1             1
# 2  201807  TRAIN_000002       1  30대       C          1             1
# 3  201807  TRAIN_000003       2  40대       D          1             1
# 4  201807  TRAIN_000004       2  40대       E          1             1
# 5  201807  TRAIN_000005       2  30대       E          1             1
# 6  201807  TRAIN_000006       1  20대       E          1             1
# 7  201807  TRAIN_000007       2  60대       E          1             1
# 8  201807  TRAIN_000008       1  30대       C          1             1
# 9  201807  TRAIN_000009       1  20대       E          1             0
#
#    회원여부_이용가능_카드론  소지여부_신용  소지카드수_유효_신용  ...  할인금액_제휴연회비_B0M  청구금액_기본연회비_B0M  \
# 0              0        1            1  ...               0               0
# 1              1        1            1  ...               0               0
# 2              0        1            1  ...               0               0
# 3              0        1            2  ...               0               0
# 4              1        1            1  ...               0               0
# 5              0        1            1  ...               0               0
# 6              0        1            1  ...               0               0
# 7              1        1            2  ...               0               0
# 8              1        1            3  ...               0               0
# 9              0        1            1  ...               0               0
#
#    청구금액_제휴연회비_B0M  상품관련면제카드수_B0M  임직원면제카드수_B0M  우수회원면제카드수_B0M  기타면제카드수_B0M  \
# 0               0             0개            0개             0개           0개
# 1               0             0개            0개             0개           0개
# 2               0             0개            0개             0개           0개
# 3               0             0개            0개             0개           0개
# 4               0             0개            0개             0개           0개
# 5               0             0개            0개             0개           0개
# 6               0             0개            0개             0개           0개
# 7               0             0개            0개             0개           0개
# 8               0             0개            0개             0개           0개
# 9               0             0개            0개             0개           0개
#
#    카드신청건수  Life_Stage  최종카드발급경과월
# 0       0     자녀성장(2)         22
# 1       0     자녀성장(1)         18
# 2       0       자녀출산기         20
# 3       1     자녀성장(2)         17
# 4       1     자녀성장(1)         15
# 5       0     자녀성장(1)         51
# 6       0          독신          6
# 7       0        노년생활         28
# 8       1       자녀출산기          5
# 9       0          독신         10
#
# [10 rows x 78 columns]

# %%
# 컬럼명 확인
all_df.columns
# Out:
# Index(['기준년월', 'ID', '남녀구분코드', '연령', 'Segment', '회원여부_이용가능', '회원여부_이용가능_CA',
#        '회원여부_이용가능_카드론', '소지여부_신용', '소지카드수_유효_신용', '소지카드수_이용가능_신용', '입회일자_신용',
#        '입회경과개월수_신용', '회원여부_연체', '이용거절여부_카드론', '동의여부_한도증액안내', '수신거부여부_TM',
#        '수신거부여부_DM', '수신거부여부_메일', '수신거부여부_SMS', '가입통신회사코드', '탈회횟수_누적',
#        '최종탈회후경과월', '탈회횟수_발급6개월이내', '탈회횟수_발급1년이내', '거주시도명', '직장시도명', '마케팅동의여부',
#        '유효카드수_신용체크', '유효카드수_신용', '유효카드수_신용_가족', '유효카드수_체크', '유효카드수_체크_가족',
#        '이용가능카드수_신용체크', '이용가능카드수_신용', '이용가능카드수_신용_가족', '이용가능카드수_체크',
#        '이용가능카드수_체크_가족', '이용카드수_신용체크', '이용카드수_신용', '이용카드수_신용_가족', '이용카드수_체크',
#        '이용카드수_체크_가족', '이용금액_R3M_신용체크', '이용금액_R3M_신용', '이용금액_R3M_신용_가족',
#        '이용금액_R3M_체크', '이용금액_R3M_체크_가족', '_1순위카드이용금액', '_1순위카드이용건수',
#        '_1순위신용체크구분', '_2순위카드이용금액', '_2순위카드이용건수', '_2순위신용체크구분',
#        '최종유효년월_신용_이용가능', '최종유효년월_신용_이용', '최종카드발급일자', '보유여부_해외겸용_본인',
#        '이용가능여부_해외겸용_본인', '이용여부_3M_해외겸용_본인', '보유여부_해외겸용_신용_본인',
#        '이용가능여부_해외겸용_신용_본인', '이용여부_3M_해외겸용_신용_본인', '연회비발생카드수_B0M',
#        '연회비할인카드수_B0M', '기본연회비_B0M', '제휴연회비_B0M', '할인금액_기본연회비_B0M',
#        '할인금액_제휴연회비_B0M', '청구금액_기본연회비_B0M', '청구금액_제휴연회비_B0M', '상품관련면제카드수_B0M',
#        '임직원면제카드수_B0M', '우수회원면제카드수_B0M', '기타면제카드수_B0M', '카드신청건수', 'Life_Stage',
#        '최종카드발급경과월'],
#       dtype='object')

# %% [markdown]
# ### 결측치 확인

# %%
# 결측치 확인
all_df.isna().sum()
# Out:
# 기준년월             0
# ID               0
# 남녀구분코드           0
# 연령               0
# Segment          0
#                 ..
# 우수회원면제카드수_B0M    0
# 기타면제카드수_B0M      0
# 카드신청건수           0
# Life_Stage       0
# 최종카드발급경과월        0
# Length: 78, dtype: int64

# %%
# 결측치가 하나라도 있는 컬럼 이름만 보기
all_df.columns[all_df.isna().any()]
# Out:
# Index(['가입통신회사코드', '직장시도명', '_1순위신용체크구분', '_2순위신용체크구분', '최종유효년월_신용_이용가능',
#        '최종유효년월_신용_이용', '최종카드발급일자'],
#       dtype='object')

# %% [markdown]
# ## Segment 분포 자체 확인

# %%
# Segment 분포 확인
print(all_df['Segment'].value_counts())
print(all_df['Segment'].value_counts(normalize=True))  # 비율
# Out:
# Segment
# E    1922052
# D     349242
# C     127590
# A        972
# B        144
# Name: count, dtype: int64
# Segment
# E    0.800855
# D    0.145517
# C    0.053163
# A    0.000405
# B    0.000060
# Name: proportion, dtype: float64

# %% [markdown]
# ## AB , CDE 그룹 생성 후 비교

# %%
# 1. 그룹 컬럼 생성 (AB , CDE)
all_df['Group'] = all_df['Segment'].apply(lambda x: 'AB' if x in ['A', 'B'] else 'CDE')
all_df['Group']
# Out:
# 0          CDE
# 1          CDE
# 2          CDE
# 3          CDE
# 4          CDE
#           ...
# 2399995    CDE
# 2399996    CDE
# 2399997    CDE
# 2399998    CDE
# 2399999    CDE
# Name: Group, Length: 2400000, dtype: object

# %%
from scipy.stats import ttest_ind


# 수치형 컬럼 리스트
num_cols = all_df.select_dtypes(include='number').columns.tolist()

# Group, Segment 컬럼 제외
num_cols = [col for col in num_cols if col not in ['Segment', 'Group']]

# A와 B 그룹별 평균 차이 계산
diff_list = []

for col in num_cols:
    ab_vals = all_df[all_df['Group'] == 'AB'][col].dropna()
    cde_vals = all_df[all_df['Group'] == 'CDE'][col].dropna()
    
    mean_ab = ab_vals.mean()
    mean_cde = cde_vals.mean()
    diff = abs(mean_ab - mean_cde)
    
    # t-test
    t_stat, p_value = ttest_ind(ab_vals, cde_vals, equal_var=False)
    
    diff_list.append({
        '컬럼': col,
        'AB평균': mean_ab,
        'CDE평균': mean_cde,
        '평균차이': diff,
        'p-value': p_value
    })

diff_df = pd.DataFrame(diff_list)

# 차이 기준으로 정렬
diff_df = diff_df.sort_values(by='평균차이', ascending=False)
diff_df.head(20)
# Out:
#                 컬럼          AB평균         CDE평균          평균차이        p-value
# 8          입회일자_신용  2.002341e+07  2.012262e+07  99216.490305  1.094029e-270
# 38     이용금액_R3M_신용  9.598651e+04  1.524928e+04  80737.225982   0.000000e+00
# 37   이용금액_R3M_신용체크  9.739123e+04  1.690002e+04  80491.210342   0.000000e+00
# 42      _1순위카드이용금액  7.198636e+04  1.099248e+04  60993.874762   0.000000e+00
# 44      _2순위카드이용금액  1.242197e+04  3.368202e+03   9053.771170  2.129649e-122
# 39  이용금액_R3M_신용_가족  4.017210e+03  2.791105e+02   3738.099196   6.807823e-86
# 48        최종카드발급일자  2.016549e+07  2.016491e+07    574.028325   7.405583e-02
# 40     이용금액_R3M_체크  1.404664e+03  1.650676e+03    246.012151   2.329011e-01
# 9       입회경과개월수_신용  1.923978e+02  7.354747e+01    118.850384  3.758434e-272
# 43      _1순위카드이용건수  1.256980e+02  3.930558e+01     86.392453  1.643234e-247
# 45      _2순위카드이용건수  4.231900e+01  1.430815e+01     28.010845   8.598544e-98
# 47    최종유효년월_신용_이용  2.021342e+05  2.021529e+05     18.698994   1.667267e-09
# 46  최종유효년월_신용_이용가능  2.021422e+05  2.021508e+05      8.635479   1.029615e-02
# 18        최종탈회후경과월  2.385573e+01  2.726149e+01      3.405755   3.036990e-03
# 28      이용가능카드수_신용  2.603047e+00  1.408409e+00      1.194637  6.303970e-159
# 33        이용카드수_신용  2.368280e+00  1.174267e+00      1.194012  1.122226e-185
# 32      이용카드수_신용체크  2.491935e+00  1.334371e+00      1.157565  6.092598e-166
# 27    이용가능카드수_신용체크  3.093190e+00  1.968121e+00      1.125069   1.021612e-98
# 23        유효카드수_신용  2.632616e+00  1.526082e+00      1.106534  2.963805e-138
# 22      유효카드수_신용체크  3.137097e+00  2.089294e+00      1.047803   7.421379e-87

# %% [markdown]
# ### 평균차이
# - 평균차이가 클수록 그룹간 구분력이 크다
#
# ### p-value
# - p-vlaue가 작을수록 통계적으로 유의미한 차이를 나타낸다.

# %%
# 먼저 평균차이 큰 순으로 30개 선택
top30_df = diff_df.sort_values(by='평균차이', ascending=False).head(30)

# p-value 조건 + 평균차이 ≥ 1 조건 함께 적용
selected_df = top30_df[(top30_df['p-value'] < 0.05) & (top30_df['평균차이'] >= 1)]

# 컬럼 리스트 추출
selected_features = selected_df['컬럼'].tolist()
print(selected_features)
# Out:
# ['입회일자_신용', '이용금액_R3M_신용', '이용금액_R3M_신용체크', '_1순위카드이용금액', '_2순위카드이용금액', '이용금액_R3M_신용_가족', '입회경과개월수_신용', '_1순위카드이용건수', '_2순위카드이용건수', '최종유효년월_신용_이용', '최종유효년월_신용_이용가능', '최종탈회후경과월', '이용가능카드수_신용', '이용카드수_신용', '이용카드수_신용체크', '이용가능카드수_신용체크', '유효카드수_신용', '유효카드수_신용체크']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

top_cols = selected_features  # 아까 만든 컬럼 리스트 그대로 사용

# 그리드 사이즈 자동 설정
n_cols = 5
n_rows = (len(top_cols) + n_cols - 1) // n_cols

fig, axes = plt.subplots(nrows=n_rows, ncols=n_cols, figsize=(4 * n_cols, 5 * n_rows))

# 2차원 배열 flatten
axes = axes.flatten()

for ax, col in zip(axes, top_cols):
    sns.boxplot(x='Group', y=col, data=all_df, ax=ax)
    ax.set_title(col)

# 사용하지 않는 빈 subplot 숨김 처리
for ax in axes[len(top_cols):]:
    ax.set_visible(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 범주형 데이터
# - 1. 회원정보 데이터에서 범주형 데이터는 피처 선택에 제외

# %%
import pandas as pd
from scipy.stats import chi2_contingency
import numpy as np

def cramers_v(confusion_matrix):
    chi2 = chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum().sum()
    phi2 = chi2 / n
    r, k = confusion_matrix.shape
    phi2corr = max(0, phi2 - ((k-1)*(r-1))/(n-1))
    rcorr = r - ((r-1)**2)/(n-1)
    kcorr = k - ((k-1)**2)/(n-1)
    return np.sqrt(phi2corr / min((kcorr-1), (rcorr-1)))

cat_cols = all_df.select_dtypes(exclude='number').columns.tolist()
result_list = []

for col in cat_cols:
    if col in ['Segment', 'Group', 'ID']:
        continue
    
    ctab = pd.crosstab(all_df[col], all_df['Group'])
    
    # 카이제곱 검정
    chi2, p, dof, ex = chi2_contingency(ctab)
    
    # Cramér's V
    cv = cramers_v(ctab)
    
    result_list.append({
        '컬럼': col,
        'p-value': p,
        "Cramér's V": cv
    })

cramer_df = pd.DataFrame(result_list).sort_values(by="Cramér's V", ascending=False)
print(cramer_df)
# Out:
#                컬럼       p-value  Cramér's V
# 5      _2순위신용체크구분  2.663366e-76    0.015373
# 3           직장시도명  5.155737e-54    0.011450
# 11     Life_Stage  9.533542e-63    0.011150
# 0              연령  2.031220e-59    0.010794
# 1        가입통신회사코드  1.683554e-28    0.007910
# 2           거주시도명  1.151440e-24    0.007589
# 4      _1순위신용체크구분  1.756523e-09    0.003854
# 6    연회비발생카드수_B0M  5.586753e-01    0.000000
# 7   상품관련면제카드수_B0M  1.000000e+00         NaN
# 8    임직원면제카드수_B0M  1.000000e+00         NaN
# 9   우수회원면제카드수_B0M  1.000000e+00         NaN
# 10    기타면제카드수_B0M  1.000000e+00         NaN

# %% [markdown]
# # VIF 분석

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
import pandas as pd

X = all_df[selected_features].dropna()

vif_df = pd.DataFrame()
vif_df["Feature"] = X.columns
vif_df["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

# VIF를 정수형으로 변환
vif_df["VIF"] = vif_df["VIF"].round(3)

# 정렬 후 출력
print(vif_df.sort_values(by="VIF", ascending=False))
# Out:
#            Feature          VIF
# 0          입회일자_신용  3425826.349
# 17      유효카드수_신용체크      231.622
# 15    이용가능카드수_신용체크      225.901
# 16        유효카드수_신용      143.428
# 12      이용가능카드수_신용      140.905
# 1      이용금액_R3M_신용       84.271
# 3       _1순위카드이용금액       40.094
# 6       입회경과개월수_신용       31.166
# 4       _2순위카드이용금액       26.719
# 13        이용카드수_신용       16.901
# 8       _2순위카드이용건수       15.030
# 2    이용금액_R3M_신용체크       14.553
# 10  최종유효년월_신용_이용가능       10.285
# 9     최종유효년월_신용_이용       10.275
# 14      이용카드수_신용체크        9.746
# 7       _1순위카드이용건수        2.840
# 5   이용금액_R3M_신용_가족        1.466
# 11        최종탈회후경과월        1.015

# %% [markdown]
# ### 상관관계 분석

# %%
# 선택한 컬럼 데이터만 추출
corr_df = all_df[selected_features].dropna()

# 상관계수 계산
corr_matrix = corr_df.corr()

# 시각화
plt.figure(figsize=(15, 12))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm", square=True)
plt.title("Feature Correlation Matrix")
plt.show()

# %%
selected_representative_features = [
    '입회경과개월수_신용',
    '이용금액_R3M_신용',
    '_1순위카드이용건수',
    '이용금액_R3M_신용_가족',
    '최종유효년월_신용_이용',
    '최종유효년월_신용_이용가능',
    '최종탈회후경과월',
    '이용카드수_신용'
]

X = all_df[selected_representative_features].dropna().copy()

vif_df = pd.DataFrame()
vif_df["Feature"] = X.columns
vif_df["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif_df["VIF"] = vif_df["VIF"].round(2)

print(vif_df.sort_values(by="VIF", ascending=False))
# Out:
#           Feature          VIF
# 5  최종유효년월_신용_이용가능  28595926.93
# 4    최종유효년월_신용_이용  28595143.38
# 7        이용카드수_신용         8.28
# 1     이용금액_R3M_신용         4.91
# 2      _1순위카드이용건수         3.71
# 0      입회경과개월수_신용         2.15
# 6        최종탈회후경과월         1.53
# 3  이용금액_R3M_신용_가족         1.32

# %%
selected_representative_features = [
    '입회경과개월수_신용',
    '이용금액_R3M_신용',
    '_1순위카드이용건수',
    '이용금액_R3M_신용_가족',
    '최종유효년월_신용_이용',
    '최종탈회후경과월',
    '이용카드수_신용'
]
X = all_df[selected_representative_features].dropna().copy()

vif_df = pd.DataFrame()
vif_df["Feature"] = X.columns
vif_df["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif_df["VIF"] = vif_df["VIF"].round(2)

print(vif_df.sort_values(by="VIF", ascending=False))
# Out:
#           Feature   VIF
# 6        이용카드수_신용  8.26
# 4    최종유효년월_신용_이용  7.56
# 1     이용금액_R3M_신용  4.91
# 2      _1순위카드이용건수  3.71
# 0      입회경과개월수_신용  2.15
# 5        최종탈회후경과월  1.53
# 3  이용금액_R3M_신용_가족  1.32

# %%
y = all_df['Group']

# %%
X = all_df[selected_representative_features].copy()

# %%
print(X.isnull().sum())
# Out:
# 입회경과개월수_신용             0
# 이용금액_R3M_신용            0
# _1순위카드이용건수             0
# 이용금액_R3M_신용_가족         0
# 최종유효년월_신용_이용      534231
# 최종탈회후경과월               0
# 이용카드수_신용               0
# dtype: int64

# %%
# 결측치 많은 컬럼 제거
X = X.drop(columns=['최종유효년월_신용_이용'])

# 다시 확인
print(X.isnull().sum())
# Out:
# 입회경과개월수_신용        0
# 이용금액_R3M_신용       0
# _1순위카드이용건수        0
# 이용금액_R3M_신용_가족    0
# 최종탈회후경과월          0
# 이용카드수_신용          0
# dtype: int64

# %%
# Feature + Target 합치기
final_df = X.copy()
final_df['Group'] = y

final_df.head()
# Out:
#    입회경과개월수_신용  이용금액_R3M_신용  _1순위카드이용건수  이용금액_R3M_신용_가족  최종탈회후경과월  이용카드수_신용  \
# 0          67          196          26               0        61         1
# 1          12        13475          46               0        98         1
# 2         124        23988          28               0        60         1
# 3          27         3904           1               0       100         1
# 4           2            0          -2               0       101         0
#
#   Group
# 0   CDE
# 1   CDE
# 2   CDE
# 3   CDE
# 4   CDE

# %%
# 저장
final_df.to_parquet("open/data/1.회원정보_train_AB_CDE_final_dataset.parquet", index=False)

# %% [markdown]
# ### 기준년월
# - 데이터 기준년월
# - int64, 범주형 데이터

# %%
# 남녀구분코드 분포
all_df['기준년월'].value_counts()
# Out:
# 기준년월
# 201807    400000
# 201808    400000
# 201809    400000
# 201810    400000
# 201811    400000
# 201812    400000
# Name: count, dtype: int64

# %% [markdown]
# ### ID
# - 고유 ID
# - object
# - 같은 고객(40만명)이 6달 동안 반복적으로 기록된 데이터...

# %%
df_august = all_df[all_df['기준년월'] == 201808]
df_august.head()
# Out:
#           기준년월            ID  남녀구분코드   연령 Segment  회원여부_이용가능  회원여부_이용가능_CA  \
# 400000  201808  TRAIN_000000       2  40대       D          1             1
# 400001  201808  TRAIN_000001       1  30대       E          1             1
# 400002  201808  TRAIN_000002       1  30대       C          1             1
# 400003  201808  TRAIN_000003       2  40대       D          1             1
# 400004  201808  TRAIN_000004       2  40대       E          1             1
#
#         회원여부_이용가능_카드론  소지여부_신용  소지카드수_유효_신용  ...  할인금액_제휴연회비_B0M  \
# 400000              0        1            1  ...               0
# 400001              1        1            1  ...               0
# 400002              0        1            1  ...               0
# 400003              0        1            2  ...               0
# 400004              1        1            1  ...               0
#
#         청구금액_기본연회비_B0M  청구금액_제휴연회비_B0M  상품관련면제카드수_B0M  임직원면제카드수_B0M  \
# 400000               0               0             0개            0개
# 400001               0               0             0개            0개
# 400002               0               0             0개            0개
# 400003               0               0             0개            0개
# 400004               0               0             0개            0개
#
#         우수회원면제카드수_B0M  기타면제카드수_B0M  카드신청건수  Life_Stage  최종카드발급경과월
# 400000             0개           0개       0     자녀성장(2)         23
# 400001             0개           0개       0     자녀성장(1)         19
# 400002             0개           0개       0       자녀출산기         21
# 400003             0개           0개       1     자녀성장(2)         18
# 400004             0개           0개       1     자녀성장(1)         16
#
# [5 rows x 78 columns]

# %%
# 총 ID 수 (전체 행 수)
len(all_df)
# Out:
# 2400000

# %%
# 고유한 고객 수
all_df['ID'].nunique()
# Out:
# 400000

# %% [markdown]
# ### 남녀구분코드
# - 범주형 데이터, int64
# - 1 / 2 로 구분되어있음.
# - 1 : 남성
# - 2 : 여성

# %%
# 남녀구분코드 분포
all_df['남녀구분코드'].value_counts()
# Out:
# 남녀구분코드
# 1    1255308
# 2    1144692
# Name: count, dtype: int64

# %% [markdown]
# ### 연령
# - 나이
# - 범주형 데이터
# - 20대, 30대, ..., 60대, 70대 이상

# %%
# 연령 분포
all_df['연령'].value_counts()
# Out:
# 연령
# 40대      733146
# 30대      592146
# 50대      546342
# 60대      246990
# 20대      191880
# 70대이상     89496
# Name: count, dtype: int64

# %% [markdown]
# ### Segment

# %%
# Segment 분포
all_df['Segment'].value_counts()
# Out:
# Segment
# E    1922052
# D     349242
# C     127590
# A        972
# B        144
# Name: count, dtype: int64

# %% [markdown]
# ### 회원여부_이용가능
# - 분실/연체/한도 소진 등으로 Black List로 등재 되지 않은 회원
# - 0 / 1 로 구분되어 있음
# - 보통 관례적으로 1 = 이용가능, 0 = 이용불가

# %%
# 회원여부_이용가능 분포
all_df['회원여부_이용가능'].value_counts()
# Out:
# 회원여부_이용가능
# 1    2286180
# 0     113820
# Name: count, dtype: int64

# %% [markdown]
# ### 회원여부_이용가능_CA
# - 분실/연체/한도 소진 등으로 Black List로 등재 되지 않아 현금서비스
# - 0 / 1 로 구분되어 있음
# - 보통 관례적으로 1 = 이용가능, 0 = 이용불가

# %%
# 회원여부_이용가능_CA 분포
all_df['회원여부_이용가능_CA'].value_counts()
# Out:
# 회원여부_이용가능_CA
# 1    2112243
# 0     287757
# Name: count, dtype: int64

# %% [markdown]
# ### 회원여부_이용가능_카드론
# - 분실/연체/한도 소진 등으로 Black List로 등재 되지 않아 카드장기대출
# - 0 / 1 로 구분되어 있음
# - 보통 관례적으로 1 = 이용가능, 0 = 이용불가

# %%
# 회원여부_이용가능_카드론 분포
all_df['회원여부_이용가능_카드론'].value_counts()
# Out:
# 회원여부_이용가능_카드론
# 1    1491148
# 0     908852
# Name: count, dtype: int64

# %% [markdown]
# ### 소지여부_신용
# - 신용카드를 소지한 회원
# - 0 / 1 로 구분되어 있음
# - 1 = 있음, 0 = 없음

# %%
# 소지여부_분포
all_df['소지여부_신용'].value_counts()
# Out:
# 소지여부_신용
# 1    2358113
# 0      41887
# Name: count, dtype: int64

# %% [markdown]
# ### 소지카드수_유효_신용
# - 유효한 신용카드의 보유 수
# - 보유 카드 수 : 0, 1, 2, 3, 4장

# %%
# 소지카드수_유효_신용
all_df['소지카드수_유효_신용'].value_counts()
# Out:
# 소지카드수_유효_신용
# 1    1845949
# 2     391523
# 3     120560
# 0      41882
# 4         86
# Name: count, dtype: int64

# %%
all_df['소지카드수_유효_신용'].value_counts().plot.pie(autopct='%.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### 소지카드수_이용가능_신용
# - 유요한 신용카드 중 BL로 등재되지 않아 이용 가능한 신용카드 수
# - 이용가능 소지카드 수 : 0, 1, 2, 3장

# %%
# 소지카드수_이용가능_신용
all_df['소지카드수_이용가능_신용'].value_counts()
# Out:
# 소지카드수_이용가능_신용
# 1    1723263
# 2     370561
# 0     205225
# 3     100951
# Name: count, dtype: int64

# %%
all_df['소지카드수_이용가능_신용'].value_counts().plot.pie(autopct='%.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### 입회일자_신용
# - 카드회원이 된 일자 (입회일자의 일단위 두자리는 01로 변경하여 월단위로 범주화)

# %%
# 입회일자_신용
all_df['입회일자_신용'].value_counts()
# Out:
# 입회일자_신용
# 20180601    312138
# 20171201     25266
# 20180101     24882
# 20180301     24606
# 20170801     24486
#              ...
# 19911101        18
# 19910501         6
# 19910901         6
# 19901101         6
# 19910801         6
# Name: count, Length: 325, dtype: int64

# %%
all_df['입회일자_신용'].hist(bins=50)
plt.xlabel('입회일자_신용')
plt.ylabel('빈도')
plt.title('입회일자_신용')
plt.show()

desc = all_df['입회일자_신용'].describe()
print(desc.apply(lambda x: int(x)))

# 이상치 탐색
sns.boxplot(x=all_df['입회일자_신용'])
# Out:
# count     2400000
# mean     20122577
# std         60464
# min      19901101
# 25%      20100301
# 50%      20140701
# 75%      20170601
# max      20180601
# Name: 입회일자_신용, dtype: int64
# <Axes: xlabel='입회일자_신용'>

# %%
# 연도, 월 컬럼 추출
all_df['입회연도'] = all_df['입회일자_신용'] // 10000
all_df['입회월'] = (all_df['입회일자_신용'] % 10000) // 100

# 연도별 가입자 수
yearly_counts = all_df['입회연도'].value_counts().sort_index()
yearly_counts.plot(kind='bar', figsize=(12, 4))
plt.title('연도별 입회자 수')
plt.xlabel('연도')
plt.ylabel('가입자 수')
plt.show()

# %% [markdown]
# ### 입회경과개월수_신용
# - 신용카드를 소지한 이후 경과 개월 수

# %%
# 입회경과개월수_신용
all_df['입회경과개월수_신용'].value_counts()
# Out:
# 입회경과개월수_신용
# 6      119886
# 5       64069
# 4       59968
# 3       55969
# 2       52023
#         ...
# 334         1
# 329         1
# 335         1
# 330         1
# 336         1
# Name: count, Length: 335, dtype: int64

# %%
all_df['입회경과개월수_신용'].hist(bins=50)
plt.xlabel('입회경과개월수_신용')
plt.title('입회경과개월수_신용')
plt.show()

desc = all_df['입회경과개월수_신용'].describe()
print(desc.apply(lambda x: int(x)))

# 이상치 탐색
sns.boxplot(x=all_df['입회경과개월수_신용'])
# Out:
# count    2400000
# mean          73
# std           72
# min            2
# 25%           17
# 50%           51
# 75%          104
# max          337
# Name: 입회경과개월수_신용, dtype: int64
# <Axes: xlabel='입회경과개월수_신용'>

# %% [markdown]
# ### 회원여부_연체
# - 연체 여부
# - 0 / 1 로 구분
# - 0 = 연체없음, 1 = 연체 있음
# - 보통 카드사/금융사에서는 1이 위험 고객군(Risky)을 의미함

# %%
# 회원여부_연체
all_df['회원여부_연체'].value_counts()
# Out:
# 회원여부_연체
# 0    2359008
# 1      40992
# Name: count, dtype: int64

# %% [markdown]
# ### 이용거절여부_카드론
# - 카드론 이용거절여부

# %%
# 카드론 이용거절여부
all_df['이용거절여부_카드론'].value_counts()
# Out:
# 이용거절여부_카드론
# 0    1925770
# 1     474230
# Name: count, dtype: int64

# %% [markdown]
# ### 동의여부_한도증액안내
# - 한도증액안내 동의여부

# %%
# 동의여부_한도증액안내
all_df['동의여부_한도증액안내'].value_counts()
# Out:
# 동의여부_한도증액안내
# 0    2163506
# 1     236494
# Name: count, dtype: int64

# %% [markdown]
# ### 수신거부여부_TM
# - TM 수신거부여부

# %%
# 수신거부여부_TM
all_df['수신거부여부_TM'].value_counts()
# Out:
# 수신거부여부_TM
# 0    1545358
# 1     854642
# Name: count, dtype: int64

# %% [markdown]
# ### 수신거부여부_DM
# - DM 수신거부여부

# %%
# 수신거부여부_DM
all_df['수신거부여부_DM'].value_counts()
# Out:
# 수신거부여부_DM
# 0    1646080
# 1     753920
# Name: count, dtype: int64

# %% [markdown]
# ### 수신거부여부_메일
# - 메일 수신거부여부

# %%
# 수신거부여부_메일
all_df['수신거부여부_메일'].value_counts()
# Out:
# 수신거부여부_메일
# 0    1632571
# 1     767429
# Name: count, dtype: int64

# %% [markdown]
# ### 수신거부여부_SMS
# - SMS 수신거부여부

# %%
# 수신거부여부_SMS
all_df['수신거부여부_SMS'].value_counts(dropna=False)
# Out:
# 수신거부여부_SMS
# 0    1513438
# 1     886562
# Name: count, dtype: int64

# %% [markdown]
# ### 가입통신회사코드
# - 가입한 통신사 구분 코드
# - 결측치 존재 (16.15%)
# - S사, K사, L사

# %%
all_df['가입통신회사코드'].value_counts(dropna=False)
# Out:
# 가입통신회사코드
# S사      995637
# K사      565208
# L사      451585
# None    387570
# Name: count, dtype: int64

# %%
na_count = all_df['가입통신회사코드'].isna().sum()
total_count = len(all_df)
print(f"결측치 개수: {na_count}개 ({na_count / total_count:.2%})")
# Out:
# 결측치 개수: 387570개 (16.15%)

# %% [markdown]
# ### 탈회횟수_누적
# - 누적 탈회횟수

# %%
all_df['탈회횟수_누적'].value_counts(dropna=False)
# Out:
# 탈회횟수_누적
# 0    1403785
# 1     759487
# 2     236728
# Name: count, dtype: int64

# %%
all_df['탈회횟수_누적'].value_counts().plot.pie(autopct='%.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### 최종탈회후경과월
# - 최종탈회 이후  경과 개월 수
# - 0 개월이 가장 많음 : 방금 탈회했거나 이번 달 탈회한 사람들
# - Max : 117 개월 -> 9년 9개월 경과

# %%
all_df['최종탈회후경과월'].value_counts(dropna=False)
# Out:
# 최종탈회후경과월
# 0      1411713
# 47       76113
# 46       75812
# 48       73304
# 45       64384
#         ...
# 117          2
# 15           1
# 89           1
# 39           1
# 53           1
# Name: count, Length: 71, dtype: int64

# %%
all_df['최종탈회후경과월'].hist(bins=50)
plt.xlabel('최종탈회후경과월')
plt.title('최종탈회후경과월')
plt.show()

desc = all_df['최종탈회후경과월'].describe()
print(desc.apply(lambda x: int(x)))

# 이상치 탐색
sns.boxplot(x=all_df['최종탈회후경과월'])
# Out:
# count    2400000
# mean          27
# std           38
# min            0
# 25%            0
# 50%            0
# 75%           48
# max          117
# Name: 최종탈회후경과월, dtype: int64
# <Axes: xlabel='최종탈회후경과월'>

# %% [markdown]
# ### 탈회횟수_발급6개월이내
# - 발급6개월 이내 탈회 횟수
# - 0 / 1 로 구분되어 있음.

# %%
all_df['탈회횟수_발급6개월이내'].value_counts(dropna=False)
# Out:
# 탈회횟수_발급6개월이내
# 0    2302195
# 1      97805
# Name: count, dtype: int64

# %% [markdown]
# ### 탈회횟수_발급1년이내
# - 발급1년 이내 탈회 횟수
# - 0 / 1 로 구분되어 있음

# %%
all_df['탈회횟수_발급1년이내'].value_counts(dropna=False)
# Out:
# 탈회횟수_발급1년이내
# 0    2245718
# 1     154282
# Name: count, dtype: int64

# %% [markdown]
# ### 거주시도명
# - 17개 광역시도명
# (서울, 부산, 대구, 인천, 광주, 대전, 울산, 세종, 경기, 강원, 충북, 충남, 전북, 전남, 경북, 경남, 제주)

# %%
all_df['거주시도명'].value_counts(dropna=False)
# Out:
# 거주시도명
# 서울    692656
# 경기    652987
# 인천    162815
# 부산    149007
# 대전    142800
# 충북    110601
# 경남     96244
# 경북     91237
# 대구     80687
# 울산     70491
# 전남     55304
# 광주     36659
# 충남     30091
# 전북     13572
# 강원     12156
# 제주      2544
# 세종       149
# Name: count, dtype: int64

# %% [markdown]
# ### 직장시도명
# - 결측치 존재 (10.21%)

# %%
all_df['직장시도명'].value_counts(dropna=False)
# Out:
# 직장시도명
# 경기      598244
# 서울      576618
# None    244969
# 인천      146944
# 부산      131285
# 대전      120697
# 충북      103951
# 경남       94527
# 경북       82975
# 대구       76605
# 울산       66275
# 전남       52849
# 광주       34100
# 충남       28361
# 전북       20442
# 강원       15485
# 세종        3117
# 제주        2556
# Name: count, dtype: int64

# %%
na_count = all_df['직장시도명'].isna().sum()
total_count = len(all_df)
print(f"결측치 개수: {na_count}개 ({na_count / total_count:.2%})")
# Out:
# 결측치 개수: 244969개 (10.21%)

# %% [markdown]
# ### 마케팅동의여부
# - 마케팅 동의 여부

# %%
all_df['직장시도명'].value_counts(dropna=False)
# Out:
# 마케팅동의여부
# 1    1944017
# 0     455983
# Name: count, dtype: int64

# %% [markdown]
# ### 유효카드수_신용체크
# - 유효한 카드수 (신용체크)

# %%
all_df['유효카드수_신용체크'].value_counts(dropna=False)
# Out:
# 유효카드수_신용체크
# 1    936149
# 2    709422
# 3    404994
# 4    203891
# 5     79437
# 0     29233
# 6     26423
# 7      9395
# 8      1056
# Name: count, dtype: int64

# %% [markdown]
# ### 유효카드수_신용_가족

# %%
all_df['유효카드수_신용_가족'].value_counts(dropna=False)
# Out:
# 유효카드수_신용_가족
# 0    2331548
# 1      49336
# 2      19116
# Name: count, dtype: int64

# %% [markdown]
# ### 유효카드수_체크

# %%
all_df['유효카드수_체크'].value_counts(dropna=False)
# Out:
# 유효카드수_체크
# 0    1436752
# 1     661328
# 2     215445
# 3      86475
# Name: count, dtype: int64

# %% [markdown]
# ### 유효카드수_체크_가족

# %%
all_df['유효카드수_체크_가족'].value_counts(dropna=False)
# Out:
# 유효카드수_체크_가족
# 0    2399964
# 1         35
# 2          1
# Name: count, dtype: int64

# %% [markdown]
# ### 이용가능카드수_신용체크

# %%
all_df['이용가능카드수_신용체크'].value_counts(dropna=False)
# Out:
# 이용가능카드수_신용체크
# 1    945107
# 2    692678
# 3    358846
# 4    185705
# 0    111452
# 5     72702
# 6     24067
# 7      8532
# 8       911
# Name: count, dtype: int64

# %% [markdown]
# ### 이용가능카드수_신용

# %%
all_df['이용가능카드수_신용'].value_counts(dropna=False)
# Out:
# 이용가능카드수_신용
# 1    1443851
# 2     486521
# 0     188157
# 3     175252
# 4      92228
# 5      13991
# Name: count, dtype: int64

# %% [markdown]
# ### 이용가능카드수_신용_가족

# %%
all_df['이용가능카드수_신용_가족'].value_counts(dropna=False)
# Out:
# 이용가능카드수_신용_가족
# 0    2331859
# 1      49106
# 2      19035
# Name: count, dtype: int64

# %% [markdown]
# ### 이용가능카드수_체크

# %%
all_df['이용가능카드수_체크'].value_counts(dropna=False)
# Out:
# 이용가능카드수_체크
# 0    1439532
# 1     662696
# 2     212783
# 3      84989
# Name: count, dtype: int64

# %% [markdown]
# ### 이용가능카드수_체크_가족

# %%
all_df['이용가능카드수_체크_가족'].value_counts(dropna=False)
# Out:
# 이용가능카드수_체크_가족
# 0    2399983
# 1         14
# 2          3
# Name: count, dtype: int64

# %% [markdown]
# ### 이용카드수_신용체크
# - 이용 중인 카드수 (신용체크)

# %%
all_df['이용카드수_신용체크'].value_counts(dropna=False)
# Out:
# 이용카드수_신용체크
# 1    1125925
# 2     536157
# 0     433328
# 3     222779
# 4      72103
# 5       9454
# 6        254
# Name: count, dtype: int64

# %% [markdown]
# ### 이용카드수_신용

# %%
all_df['이용카드수_신용'].value_counts(dropna=False)
# Out:
# 이용카드수_신용
# 1    1250336
# 0     492003
# 2     456168
# 3     149119
# 4      52325
# 5         49
# Name: count, dtype: int64

# %% [markdown]
# ### 이용카드수_체크

# %%
all_df['이용카드수_체크'].value_counts(dropna=False)
# Out:
# 이용카드수_체크
# 0    2022815
# 1     370162
# 2       7023
# Name: count, dtype: int64

# %% [markdown]
# ### 이용카드수_체크_가족

# %%
all_df['이용카드수_체크_가족'].value_counts(dropna=False)
# Out:
# 이용카드수_체크_가족
# 0    2400000
# Name: count, dtype: int64

# %% [markdown]
# ### 이용금액_R3M_신용체크
# - 이용금액 (최근3개월간)_신용체크

# %%
all_df['이용금액_R3M_신용체크'].value_counts(dropna=False)
# Out:
# 이용금액_R3M_신용체크
# 0         442011
# 2184         122
# 1643         115
# 1945         115
# 1857         115
#            ...
# 109770         1
# 111667         1
# 89913          1
# 127851         1
# 116441         1
# Name: count, Length: 124193, dtype: int64

# %%
all_df['이용금액_R3M_신용체크'].hist(bins=50)
plt.xlabel('이용금액_R3M_신용체크')
plt.title('이용금액_R3M_신용체크')
plt.show()

desc = all_df['이용금액_R3M_신용체크'].describe()
print(desc.apply(lambda x: int(x)))

# 이상치 탐색
sns.boxplot(x=all_df['이용금액_R3M_신용체크'])
# Out:
# count    2400000
# mean       16937
# std        23247
# min        -8749
# 25%          432
# 50%         8879
# 75%        21793
# max       235195
# Name: 이용금액_R3M_신용체크, dtype: int64
# <Axes: xlabel='이용금액_R3M_신용체크'>

# %% [markdown]
# ### 이용금액_R3M_신용
# - 마이너스값 존재함..

# %%
all_df['이용금액_R3M_신용'].hist(bins=50)
plt.xlabel('이용금액_R3M_신용')
plt.title('이용금액_R3M_신용')
plt.show()

desc = all_df['이용금액_R3M_신용'].describe()
print(desc.apply(lambda x: int(x)))

# 이상치 탐색
sns.boxplot(x=all_df['이용금액_R3M_신용'])
# Out:
# count    2400000
# mean       15286
# std        21898
# min        -8749
# 25%            0
# 50%         7681
# 75%        19568
# max       163706
# Name: 이용금액_R3M_신용, dtype: int64
# <Axes: xlabel='이용금액_R3M_신용'>

# %% [markdown]
# ### 이용금액_R3M_신용_가족

# %%
all_df['이용금액_R3M_신용체크'].value_counts(dropna=False)
# Out:
# 이용금액_R3M_신용체크
# 0         442011
# 2184         122
# 1643         115
# 1945         115
# 1857         115
#            ...
# 109770         1
# 111667         1
# 89913          1
# 127851         1
# 116441         1
# Name: count, Length: 124193, dtype: int64

# %%
all_df['이용금액_R3M_신용_가족'].hist(bins=50)
plt.xlabel('이용금액_R3M_신용_가족')
plt.title('이용금액_R3M_신용_가족')
plt.show()

desc = all_df['이용금액_R3M_신용_가족'].describe()
print(desc.apply(lambda x: int(x)))

# 이상치 탐색
sns.boxplot(x=all_df['이용금액_R3M_신용_가족'])
# Out:
# count    2400000
# mean         280
# std         1764
# min            0
# 25%            0
# 50%            0
# 75%            0
# max        53199
# Name: 이용금액_R3M_신용_가족, dtype: int64
# <Axes: xlabel='이용금액_R3M_신용_가족'>

# %% [markdown]
# ### 이용금액_R3M_체크

# %%
all_df['이용금액_R3M_체크'].hist(bins=50)
plt.xlabel('이용금액_R3M_체크')
plt.ylabel('빈도')
plt.title('이용금액_R3M_체크')
plt.show()

desc = all_df['이용금액_R3M_체크'].describe()
print(desc.apply(lambda x: int(x)))

# 이상치 탐색
sns.boxplot(x=all_df['이용금액_R3M_체크'])
# Out:
# count    2400000
# mean        1650
# std         7528
# min            0
# 25%            0
# 50%            0
# 75%            0
# max       163250
# Name: 이용금액_R3M_체크, dtype: int64
# <Axes: xlabel='이용금액_R3M_체크'>

# %% [markdown]
# ### 이용금액_R3M_체크_가족
# - 전부 0원

# %%
all_df['이용금액_R3M_체크_가족'].hist(bins=50)
plt.xlabel('이용금액_R3M_체크_가족')
plt.ylabel('빈도')
plt.title('이용금액_R3M_체크_가족')
plt.show()

desc = all_df['이용금액_R3M_체크_가족'].describe()
print(desc.apply(lambda x: int(x)))

# 이상치 탐색
sns.boxplot(x=all_df['이용금액_R3M_체크_가족'])
# Out:
# count    2400000
# mean           0
# std            0
# min            0
# 25%            0
# 50%            0
# 75%            0
# max            0
# Name: 이용금액_R3M_체크_가족, dtype: int64
# <Axes: xlabel='이용금액_R3M_체크_가족'>

# %%
all_df['이용금액_R3M_체크_가족'].value_counts()
# Out:
# 이용금액_R3M_체크_가족
# 0    2400000
# Name: count, dtype: int64

# %% [markdown]
# ### _1순위카드이용금액
# - 1순위 이용 카드의 이용금액
# - 마이더스 금액이 존재함...

# %%
all_df['_1순위카드이용금액'].value_counts()
# Out:
# _1순위카드이용금액
# 0        491101
# 1399        144
# 386         143
# 796         143
# 1133        142
#           ...
# 84157         1
# 89745         1
# 64520         1
# 71711         1
# 56510         1
# Name: count, Length: 81963, dtype: int64

# %%
all_df['_1순위카드이용금액'].hist(bins=50)
plt.xlabel('_1순위카드이용금액')
plt.ylabel('빈도')
plt.title('_1순위카드이용금액')
plt.show()

desc = all_df['_1순위카드이용금액'].describe()
print(desc.apply(lambda x: int(x)))

# 이상치 탐색
sns.boxplot(x=all_df['_1순위카드이용금액'])
# Out:
# count    2400000
# mean       11020
# std        14090
# min        -3925
# 25%            0
# 50%         6255
# 75%        15979
# max       118507
# Name: _1순위카드이용금액, dtype: int64
# <Axes: xlabel='_1순위카드이용금액'>

# %% [markdown]
# ### _1순위카드이용건수
# - 1순위 이용 카드의 이용 건수
# - 이용 건수에 마이너스가 있을 수 있나 ? 어떤 의미인가 ?
# - -2, -1의 의미는 ??

# %%
all_df['_1순위카드이용건수'].value_counts()
# Out:
# _1순위카드이용건수
# -2      421728
# -1       66230
#  0       65256
#  1       62980
#  2       59690
#          ...
#  220        27
#  221        16
#  222        11
#  223         3
#  224         2
# Name: count, Length: 227, dtype: int64

# %%
all_df['_1순위카드이용건수'].hist(bins=50)
plt.xlabel('_1순위카드이용건수')
plt.ylabel('빈도')
plt.title('_1순위카드이용건수')
plt.show()

desc = all_df['_1순위카드이용건수'].describe()
print(desc.apply(lambda x: int(x)))

# 이상치 탐색
sns.boxplot(x=all_df['_1순위카드이용건수'])
# Out:
# count    2400000
# mean          39
# std           51
# min           -2
# 25%            1
# 50%           17
# 75%           61
# max          224
# Name: _1순위카드이용건수, dtype: int64
# <Axes: xlabel='_1순위카드이용건수'>

# %% [markdown]
# ### _1순위신용체크구분
# - 1순위 이용 카드의 신용,체크 구분
# - 신용 / 체크 로 구분되어 있음
# - 결측치 존재함 (1.16%)

# %%
all_df['_1순위신용체크구분'].value_counts(dropna=False)
# Out:
# _1순위신용체크구분
# 신용      2295461
# 체크        76589
# None      27950
# Name: count, dtype: int64

# %%
na_count = all_df['_1순위신용체크구분'].isna().sum()
total_count = len(all_df)
print(f"결측치 개수: {na_count}개 ({na_count / total_count:.2%})")
# Out:
# 결측치 개수: 27950개 (1.16%)

# %% [markdown]
# ### _2순위카드 이용금액
# - 마이너스 이용금액 존재함.

# %%
all_df['_2순위카드이용금액'].value_counts(dropna=False)
# Out:
# _2순위카드이용금액
# 0        1711749
# 6239          78
# 5716          76
# 6017          76
# 6088          76
#           ...
# 41088          1
# 69036          1
# 49818          1
# 39054          1
# 36150          1
# Name: count, Length: 53948, dtype: int64

# %%
all_df['_2순위카드이용금액'].hist(bins=50)
plt.xlabel('_2순위카드이용금액')
plt.ylabel('빈도')
plt.title('_2순위카드이용금액')
plt.show()

desc = all_df['_2순위카드이용금액'].describe()
print(desc.apply(lambda x: int(x)))

# 이상치 탐색
sns.boxplot(x=all_df['_2순위카드이용금액'])
# Out:
# count    2400000
# mean        3372
# std         7707
# min        -4042
# 25%            0
# 50%            0
# 75%         3201
# max        84966
# Name: _2순위카드이용금액, dtype: int64
# <Axes: xlabel='_2순위카드이용금액'>

# %% [markdown]
# ### _2순위카드이용건수
# - 이용건수에 마이너스 값 있음...

# %%
all_df['_2순위카드이용건수'].value_counts(dropna=False)
# Out:
# _2순위카드이용건수
# 0      1713170
# 29       12456
# 27       12388
# 31       12297
# 30       12228
#         ...
# 206          5
# 204          4
# 205          3
# 203          3
# 209          3
# Name: count, Length: 209, dtype: int64

# %%
all_df['_2순위카드이용건수'].hist(bins=50)
plt.xlabel('_2순위카드이용건수')
plt.ylabel('빈도')
plt.title('_2순위카드이용건수')
plt.show()

desc = all_df['_2순위카드이용건수'].describe()
print(desc.apply(lambda x: int(x)))

# 이상치 탐색
sns.boxplot(x=all_df['_2순위카드이용건수'])
# Out:
# count    2400000
# mean          14
# std           29
# min           -1
# 25%            0
# 50%            0
# 75%           16
# max          209
# Name: _2순위카드이용건수, dtype: int64
# <Axes: xlabel='_2순위카드이용건수'>

# %% [markdown]
# ### _2순위신용체크구분
# - 신용 / 체크로 구분되어 있음
#
# - 결측치 존재 (39.92 %)

# %%
all_df['_2순위신용체크구분'].value_counts(dropna=False)
# Out:
# _2순위신용체크구분
# None    958115
# 신용      873447
# 체크      568438
# Name: count, dtype: int64

# %%
na_count = all_df['_2순위신용체크구분'].isna().sum()
total_count = len(all_df)
print(f"결측치 개수: {na_count}개 ({na_count / total_count:.2%})")
# Out:
# 결측치 개수: 958115개 (39.92%)

# %% [markdown]
# ### 최종유효년월_신용_이용가능
# - 이용가능한 신용카드의 최종 유효년월
# - 결측치 <Na> 문자열로 존재함.
# - 8.77 %

# %%
all_df['최종유효년월_신용_이용가능'].value_counts(dropna=False)
# Out:
# 최종유효년월_신용_이용가능
# <NA>      210447
# 202208     66949
# 202207     66486
# 202210     66020
# 202209     64576
#            ...
# 201809        62
# 201808        40
# 201807        14
# 201806         6
# 201805         2
# Name: count, Length: 75, dtype: int64

# %%
# 실제로 '<NA>' 값이 문자열인지 확인
all_df['최종유효년월_신용_이용가능'].unique()[:10]
# Out:
# array(['202110', '202112', '202111', '202201', '202002', '202211',
#        '202107', '202209', '<NA>', '202001'], dtype=object)

# %%
# 문자열 '<NA>'를 진짜 결측치로 바꾸기
all_df['최종유효년월_신용_이용가능'] = all_df['최종유효년월_신용_이용가능'].replace('<NA>', pd.NA)

# %%
na_count = all_df['최종유효년월_신용_이용가능'].isna().sum()
total_count = len(all_df)
print(f"결측치 개수: {na_count}개 ({na_count / total_count:.2%})")
# Out:
# 결측치 개수: 210447개 (8.77%)

# %% [markdown]
# ### 최종유효년월_신용_이용
# - 이용중인 신용카드의 최종 유효년월
# - 결측치 존재 (22.26%)

# %%
all_df['최종유효년월_신용_이용'].value_counts(dropna=False)
# Out:
# 최종유효년월_신용_이용
# NaN         534231
# 202207.0     62997
# 202208.0     62145
# 202210.0     60683
# 202205.0     60367
#              ...
# 201811.0        42
# 201810.0        16
# 201809.0         8
# 201807.0         2
# 201808.0         1
# Name: count, Length: 73, dtype: int64

# %%
na_count = all_df['최종유효년월_신용_이용'].isna().sum()
total_count = len(all_df)
print(f"결측치 개수: {na_count}개 ({na_count / total_count:.2%})")
# Out:
# 결측치 개수: 534231개 (22.26%)

# %% [markdown]
# ### 최종카드발급일자
# - 최종 발급받은 카드의 발급일자
# - 결측치 존재 (1.75%)

# %%
all_df['최종카드발급일자'].value_counts(dropna=False)
# Out:
# 최종카드발급일자
# NaN           41965
# 20180705.0     4011
# 20180707.0     3873
# 20180703.0     3837
# 20180701.0     3834
#               ...
# 20130818.0        6
# 20131014.0        6
# 20130919.0        6
# 20130804.0        6
# 20131015.0        6
# Name: count, Length: 1940, dtype: int64

# %%
na_count = all_df['최종카드발급일자'].isna().sum()
total_count = len(all_df)
print(f"결측치 개수: {na_count}개 ({na_count / total_count:.2%})")
# Out:
# 결측치 개수: 41965개 (1.75%)

# %% [markdown]
# ### 보유여부_해외겸용_본인
# - 해외겸용 카드 보유 여부

# %%
all_df['보유여부_해외겸용_본인'].value_counts(dropna=False)
# Out:
# 보유여부_해외겸용_본인
# 1    1876902
# 0     523098
# Name: count, dtype: int64

# %% [markdown]
# ### 이용가능여부_해외겸용_본인

# %%
all_df['이용가능여부_해외겸용_본인'].value_counts(dropna=False)
# Out:
# 이용가능여부_해외겸용_본인
# 1    1809391
# 0     590609
# Name: count, dtype: int64

# %% [markdown]
# ### 이용여부_3M_해외겸용_본인
# - 해외겸용 신용카드 최근3개월 이용 여부

# %%
all_df['이용여부_3M_해외겸용_본인'].value_counts(dropna=False)
# Out:
# 이용여부_3M_해외겸용_본인
# 1    1452960
# 0     947040
# Name: count, dtype: int64

# %% [markdown]
# ### 연회비발생카드수_BOM
# - 연회비발생카드수(당월)
# - 0개 / 1개이상

# %%
all_df['연회비발생카드수_B0M'].value_counts(dropna=False)
# Out:
# 연회비발생카드수_B0M
# 0개      2394826
# 1개이상       5174
# Name: count, dtype: int64

# %% [markdown]
# ### 연회비할인카드수_BOM
# - 연회비할인카드수(당월)
# - 전부 0 장

# %%
all_df['연회비할인카드수_B0M'].value_counts(dropna=False)
# Out:
# 연회비할인카드수_B0M
# 0    2400000
# Name: count, dtype: int64

# %% [markdown]
# ### 기본연회비_BOM
# - 기본연회비(당월)

# %%
all_df['기본연회비_B0M'].value_counts(dropna=False)
# Out:
# 기본연회비_B0M
# 0      2396961
# 108        906
# 109        639
# 107        565
# 50         381
# 106        222
# 105        120
# 104         76
# 110         67
# 103         30
# 49          25
# 111          4
# 102          3
# 101          1
# Name: count, dtype: int64

# %% [markdown]
# ### 제휴연회비_BOM
# - 제휴연회비(당월)

# %%
all_df['제휴연회비_B0M'].value_counts(dropna=False)
# Out:
# 제휴연회비_B0M
# 0      2399128
# 950        446
# 949        418
# 30           3
# 29           2
# 149          1
# 951          1
# 150          1
# Name: count, dtype: int64

# %% [markdown]
# ### 할인금액_기본연회비_BOM
# - 전부 0

# %%
all_df['할인금액_기본연회비_B0M'].value_counts()
# Out:
# 할인금액_기본연회비_B0M
# 0    2400000
# Name: count, dtype: int64

# %% [markdown]
# ### 할인금액_제휴연회비_BOM
# - 전부 0

# %%
all_df['할인금액_제휴연회비_B0M'].value_counts()
# Out:
# 할인금액_제휴연회비_B0M
# 0    2400000
# Name: count, dtype: int64

# %% [markdown]
# ### 청구금액_기본연회비_BOM

# %%
all_df['청구금액_기본연회비_B0M'].value_counts()
# Out:
# 청구금액_기본연회비_B0M
# 0      2396961
# 108        906
# 109        639
# 107        565
# 50         381
# 106        222
# 105        120
# 104         76
# 110         67
# 103         30
# 49          25
# 111          4
# 102          3
# 101          1
# Name: count, dtype: int64

# %% [markdown]
# ### 청구금액_제휴연회비_BOM

# %%
all_df['청구금액_제휴연회비_B0M'].value_counts()
# Out:
# 청구금액_제휴연회비_B0M
# 0      2399128
# 950        446
# 949        418
# 30           3
# 29           2
# 149          1
# 951          1
# 150          1
# Name: count, dtype: int64

# %% [markdown]
# ### 상품관련면제카드수_BOM
# - 전부 0개

# %%
all_df['상품관련면제카드수_B0M'].value_counts()
# Out:
# 상품관련면제카드수_B0M
# 0개    2400000
# Name: count, dtype: int64

# %% [markdown]
# ### 임직원면제카드수_BOM
# - 전부 0개

# %%
all_df['임직원면제카드수_B0M'].value_counts()
# Out:
# 임직원면제카드수_B0M
# 0개    2400000
# Name: count, dtype: int64

# %% [markdown]
# ### 우수회원면제카드수_BOM
# - 전부 0개

# %%
all_df['우수회원면제카드수_B0M'].value_counts()
# Out:
# 우수회원면제카드수_B0M
# 0개    2400000
# Name: count, dtype: int64

# %% [markdown]
# ### 기타면제카드수_BOM

# %%
all_df['기타면제카드수_B0M'].value_counts()
# Out:
# 기타면제카드수_B0M
# 0개    2400000
# Name: count, dtype: int64

# %% [markdown]
# ### 카드신청건수
# - 0건, 1건

# %%
all_df['카드신청건수'].value_counts()
# Out:
# 카드신청건수
# 0    2189218
# 1     210782
# Name: count, dtype: int64

# %% [markdown]
# ### Life_Stage
# - 생애주기 구분
# - 자녀성장(1) / 자녀성장(2) / 자녀출산기 / 가족구축기 / 노년생활 / 자녀독립기 / 독신

# %%
all_df['Life_Stage'].value_counts(dropna=False)
# Out:
# Life_Stage
# 자녀성장(1)    795610
# 자녀성장(2)    591048
# 자녀출산기      245797
# 가족구축기      242373
# 노년생활       233300
# 자녀독립기      198237
# 독신          93635
# Name: count, dtype: int64

# %% [markdown]
# ### 최종카드발급경과일

# %%
all_df['최종카드발급경과월'].value_counts()
# Out:
# 최종카드발급경과월
# 0     78140
# 14    74479
# 13    73671
# 15    73642
# 16    73152
#       ...
# 63       41
# 64       20
# 65        4
# 66        1
# 67        1
# Name: count, Length: 68, dtype: int64

# %%
# 값 개수 정렬
cnts = all_df['최종카드발급경과월'].value_counts().sort_index()

# 시각화
plt.figure(figsize=(14, 6))
sns.barplot(x=cnts.index, y=cnts.values)
plt.xticks(rotation=90)
plt.xlabel('최종카드발급경과월')
plt.ylabel('빈도')
plt.title('최종카드발급경과월 분포 (범주형 시각화)')
plt.show()

# %%
all_df['최종카드발급경과월'].describe()
# Out:
# count    2.400000e+06
# mean     2.145997e+01
# std      1.378313e+01
# min      0.000000e+00
# 25%      1.100000e+01
# 50%      1.900000e+01
# 75%      3.100000e+01
# max      6.700000e+01
# Name: 최종카드발급경과월, dtype: float64

# %%
all_df.to_csv('open/train_1.회원정보.csv', index=False)
