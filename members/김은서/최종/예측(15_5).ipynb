# %%
# 기본
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 경고 뜨지 않게 설정
import warnings
warnings.filterwarnings('ignore')

# 그래프 설정
sns.set()

# 그래프 기본 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
# plt.rcParams['font.family'] = 'AppleGothic'
plt.rcParams['figure.figsize'] = 12, 6
plt.rcParams['font.size'] = 14
plt.rcParams['axes.unicode_minus'] = False

# 데이터 전처리 알고리즘
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

# 학습용과 검증용으로 나누는 함수
from sklearn.model_selection import train_test_split

# 교차 검증
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold

# 평가함수
# 분류용
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score

# 회귀용
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# 모델의 최적의 하이퍼 파라미터를 찾기 위한 도구
from sklearn.model_selection import GridSearchCV

# 머신러닝 알고리즘 - 분류
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import VotingClassifier

# 머신러닝 알고리즘 - 회귀
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
from sklearn.ensemble import VotingRegressor

# 학습 모델 저장을 위한 라이브러리
import pickle

# %%
# 학습이 완료된 모델을 저장할 파일 이름
best_model_path = 'model/best_model_15_5.dat'

# %%
with open(best_model_path, 'rb') as fp :
    best_model = pickle.load(fp)
    scalerX = pickle.load(fp)
    scaler_columns = pickle.load(fp)
    Encoder1 = pickle.load(fp)
    Encoder2 = pickle.load(fp)
    Encoder3 = pickle.load(fp)
    Encoder4 = pickle.load(fp)
    Encoder5 = pickle.load(fp)
    Encoder6 = pickle.load(fp)
    Encoder7 = pickle.load(fp)
    le = pickle.load(fp)
    
display(best_model)
display(scalerX)
display(Encoder1)
display(Encoder2)
display(Encoder3)
display(Encoder4)
display(Encoder5)
display(Encoder6)
display(Encoder7)
display(le)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)
# StandardScaler()
# LabelEncoder()
# LabelEncoder()
# LabelEncoder()
# LabelEncoder()
# LabelEncoder()
# LabelEncoder()
# LabelEncoder()
# LabelEncoder()

# %% [markdown]
# ### Target

# %%
target1=pd.read_parquet(r'data/train/1.회원정보/201807_train_.parquet')
target2=pd.read_parquet(r'data/train/1.회원정보/201808_train_.parquet')
target3=pd.read_parquet(r'data/train/1.회원정보/201809_train_.parquet')
target4=pd.read_parquet(r'data/train/1.회원정보/201810_train_.parquet')
target5=pd.read_parquet(r'data/train/1.회원정보/201811_train_.parquet')
target6=pd.read_parquet(r'data/train/1.회원정보/201812_train_.parquet')

# %%
tg_df = pd.concat([
    target1['Segment'],
    target2['Segment'],
    target3['Segment'],
    target4['Segment'],
    target5['Segment'],
    target6['Segment']
])

tg_df = tg_df.reset_index(drop=True).to_frame(name='Segment')
tg_df
# Out:
#         Segment
# 0             D
# 1             E
# 2             C
# 3             D
# 4             E
# ...         ...
# 2399995       E
# 2399996       D
# 2399997       C
# 2399998       E
# 2399999       E
#
# [2400000 rows x 1 columns]

# %%
# 예측할 데이터를 읽어온다.
df1 = pd.read_csv('C,D(5).csv')
df1
# Out:
#           기준년월          ID  이용금액_R3M_신용체크  _1순위카드이용금액  이용카드수_신용체크 Life_Stage  \
# 0       201807  TEST_00000          21458       13852           2    자녀성장(1)
# 1       201807  TEST_00001          18681       11065           2      자녀독립기
# 2       201807  TEST_00002          40758       27071           2    자녀성장(1)
# 3       201807  TEST_00003           5255        4827           1    자녀성장(1)
# 4       201807  TEST_00004          16148        8011           3    자녀성장(1)
# ...        ...         ...            ...         ...         ...        ...
# 599995  201812  TEST_99995              0           0           0       노년생활
# 599996  201812  TEST_99996           3110        1231           1      자녀출산기
# 599997  201812  TEST_99997              0           0           0    자녀성장(1)
# 599998  201812  TEST_99998         173263       63592           6      가족구축기
# 599999  201812  TEST_99999           3016        -574           2      자녀출산기
#
#         이용개월수_신용_R12M  이용금액_일시불_R6M  이용후경과월_신판  이용건수_신용_R12M  ...  청구서발송여부_B0  \
# 0                  10         26595          0           150  ...           1
# 1                   9         -7578          0            28  ...           1
# 2                  12         48483          1           650  ...           1
# 3                   9           403          0           361  ...           1
# 4                  12          1238          0           227  ...           1
# ...               ...           ...        ...           ...  ...         ...
# 599995              0             0         12             0  ...           0
# 599996             10             3          0             7  ...           1
# 599997              0             0         12             0  ...           0
# 599998             12        133431          0           933  ...           1
# 599999             12         -4731          2            40  ...           1
#
#         할인건수_R3M  할인건수_B0M  방문횟수_앱_R6M  방문횟수_PC_R6M  인입횟수_ARS_R6M  \
# 0          1회 이상     1회 이상       1회 이상        1회 이상         1회 이상
# 1          1회 이상     1회 이상       1회 이상        1회 이상         1회 이상
# 2          1회 이상     1회 이상       1회 이상        1회 이상         1회 이상
# 3          1회 이상     1회 이상       1회 이상        1회 이상         1회 이상
# 4          1회 이상     1회 이상       1회 이상        1회 이상         1회 이상
# ...          ...       ...         ...          ...           ...
# 599995     1회 이상     1회 이상       1회 이상        1회 이상         1회 이상
# 599996     1회 이상     1회 이상      10회 이상        1회 이상         1회 이상
# 599997     1회 이상     1회 이상       1회 이상        1회 이상         1회 이상
# 599998     1회 이상     1회 이상      40회 이상        1회 이상         1회 이상
# 599999     1회 이상     1회 이상       1회 이상        1회 이상         1회 이상
#
#         이용메뉴건수_ARS_R6M  입회경과개월수_신용  _1순위카드이용건수  이용후경과월_할부_무이자
# 0                1회 이상          51          51             12
# 1                1회 이상          30          40              0
# 2                1회 이상           5         154              3
# 3                1회 이상          73         105              2
# 4                1회 이상         176          52              0
# ...                ...         ...         ...            ...
# 599995           1회 이상          69          -2             12
# 599996           1회 이상          14           4             12
# 599997           1회 이상           6           6             12
# 599998           1회 이상          82         185              2
# 599999           1회 이상          40           0             12
#
# [600000 rows x 36 columns]

# %%
notE = pd.read_csv('data/model3_notE.csv')
notE
# Out:
#                ID Segment
# 0      TEST_00002   Not_E
# 1      TEST_00010   Not_E
# 2      TEST_00012   Not_E
# 3      TEST_00016   Not_E
# 4      TEST_00032   Not_E
# ...           ...     ...
# 16078  TEST_99957   Not_E
# 16079  TEST_99961   Not_E
# 16080  TEST_99982   Not_E
# 16081  TEST_99994   Not_E
# 16082  TEST_99998   Not_E
#
# [16083 rows x 2 columns]

# %%
# 1. 'Not_E'인 ID만 필터링
filtered_ids1 = notE[notE['Segment'] == 'Not_E']['ID']

# 2. df2에서 해당 ID만 골라오기
df2 = df1[df1['ID'].isin(filtered_ids1)]

# %%
df2
# Out:
#           기준년월          ID  이용금액_R3M_신용체크  _1순위카드이용금액  이용카드수_신용체크 Life_Stage  \
# 2       201807  TEST_00002          40758       27071           2    자녀성장(1)
# 10      201807  TEST_00010          45764        7544           2    자녀성장(1)
# 12      201807  TEST_00012          37849       24425           2    자녀성장(2)
# 16      201807  TEST_00016          51440       42636           2      자녀출산기
# 32      201807  TEST_00032          54632        3885           2      자녀출산기
# ...        ...         ...            ...         ...         ...        ...
# 599957  201812  TEST_99957          61148       38644           4    자녀성장(1)
# 599961  201812  TEST_99961          30318       25961           1    자녀성장(2)
# 599982  201812  TEST_99982          94440       70955           1       노년생활
# 599994  201812  TEST_99994          31697       29020           1    자녀성장(2)
# 599998  201812  TEST_99998         173263       63592           6      가족구축기
#
#         이용개월수_신용_R12M  이용금액_일시불_R6M  이용후경과월_신판  이용건수_신용_R12M  ...  청구서발송여부_B0  \
# 2                  12         48483          1           650  ...           1
# 10                 11         19540          1            53  ...           0
# 12                 12         46059          0           555  ...           1
# 16                 12         98761          0           565  ...           1
# 32                 12         12229          2           116  ...           1
# ...               ...           ...        ...           ...  ...         ...
# 599957             12         74022          0           536  ...           1
# 599961             12         67949          1           316  ...           1
# 599982             12        129251          0           435  ...           1
# 599994              9         20070          1            20  ...           1
# 599998             12        133431          0           933  ...           1
#
#         할인건수_R3M  할인건수_B0M  방문횟수_앱_R6M  방문횟수_PC_R6M  인입횟수_ARS_R6M  \
# 2          1회 이상     1회 이상       1회 이상        1회 이상         1회 이상
# 10         1회 이상     1회 이상       1회 이상        1회 이상         1회 이상
# 12        10회 이상     1회 이상       1회 이상        1회 이상        10회 이상
# 16         1회 이상     1회 이상       1회 이상        1회 이상         1회 이상
# 32         1회 이상     1회 이상       1회 이상        1회 이상         1회 이상
# ...          ...       ...         ...          ...           ...
# 599957     1회 이상     1회 이상      40회 이상       40회 이상         1회 이상
# 599961     1회 이상     1회 이상       1회 이상        1회 이상         1회 이상
# 599982     1회 이상     1회 이상       1회 이상        1회 이상         1회 이상
# 599994     1회 이상     1회 이상       1회 이상        1회 이상         1회 이상
# 599998     1회 이상     1회 이상      40회 이상        1회 이상         1회 이상
#
#         이용메뉴건수_ARS_R6M  입회경과개월수_신용  _1순위카드이용건수  이용후경과월_할부_무이자
# 2                1회 이상           5         154              3
# 10               1회 이상          54           9             12
# 12              10회 이상          46         129              3
# 16               1회 이상          58         120              8
# 32               1회 이상         119          11             12
# ...                ...         ...         ...            ...
# 599957           1회 이상          17         115              4
# 599961          10회 이상         120          57             12
# 599982           1회 이상          92         101             12
# 599994          20회 이상          30          15              1
# 599998           1회 이상          82         185              2
#
# [96498 rows x 36 columns]

# %%
notAB = pd.read_csv('data/model3_notAB.csv')
notAB
# Out:
#                ID Segment
# 0      TEST_00002   notAB
# 1      TEST_00010   notAB
# 2      TEST_00012   notAB
# 3      TEST_00016   notAB
# 4      TEST_00032   notAB
# ...           ...     ...
# 16063  TEST_99957   notAB
# 16064  TEST_99961   notAB
# 16065  TEST_99982   notAB
# 16066  TEST_99994   notAB
# 16067  TEST_99998   notAB
#
# [16068 rows x 2 columns]

# %%
# 1. 'Not_E'인 ID만 필터링
filtered_ids2 = notAB[notAB['Segment'] == 'notAB']['ID']

# 2. df2에서 해당 ID만 골라오기
Xtest_df = df2[df2['ID'].isin(filtered_ids2)]

# %%
Xtest_df
# Out:
#           기준년월          ID  이용금액_R3M_신용체크  _1순위카드이용금액  이용카드수_신용체크 Life_Stage  \
# 2       201807  TEST_00002          40758       27071           2    자녀성장(1)
# 10      201807  TEST_00010          45764        7544           2    자녀성장(1)
# 12      201807  TEST_00012          37849       24425           2    자녀성장(2)
# 16      201807  TEST_00016          51440       42636           2      자녀출산기
# 32      201807  TEST_00032          54632        3885           2      자녀출산기
# ...        ...         ...            ...         ...         ...        ...
# 599957  201812  TEST_99957          61148       38644           4    자녀성장(1)
# 599961  201812  TEST_99961          30318       25961           1    자녀성장(2)
# 599982  201812  TEST_99982          94440       70955           1       노년생활
# 599994  201812  TEST_99994          31697       29020           1    자녀성장(2)
# 599998  201812  TEST_99998         173263       63592           6      가족구축기
#
#         이용개월수_신용_R12M  이용금액_일시불_R6M  이용후경과월_신판  이용건수_신용_R12M  ...  청구서발송여부_B0  \
# 2                  12         48483          1           650  ...           1
# 10                 11         19540          1            53  ...           0
# 12                 12         46059          0           555  ...           1
# 16                 12         98761          0           565  ...           1
# 32                 12         12229          2           116  ...           1
# ...               ...           ...        ...           ...  ...         ...
# 599957             12         74022          0           536  ...           1
# 599961             12         67949          1           316  ...           1
# 599982             12        129251          0           435  ...           1
# 599994              9         20070          1            20  ...           1
# 599998             12        133431          0           933  ...           1
#
#         할인건수_R3M  할인건수_B0M  방문횟수_앱_R6M  방문횟수_PC_R6M  인입횟수_ARS_R6M  \
# 2          1회 이상     1회 이상       1회 이상        1회 이상         1회 이상
# 10         1회 이상     1회 이상       1회 이상        1회 이상         1회 이상
# 12        10회 이상     1회 이상       1회 이상        1회 이상        10회 이상
# 16         1회 이상     1회 이상       1회 이상        1회 이상         1회 이상
# 32         1회 이상     1회 이상       1회 이상        1회 이상         1회 이상
# ...          ...       ...         ...          ...           ...
# 599957     1회 이상     1회 이상      40회 이상       40회 이상         1회 이상
# 599961     1회 이상     1회 이상       1회 이상        1회 이상         1회 이상
# 599982     1회 이상     1회 이상       1회 이상        1회 이상         1회 이상
# 599994     1회 이상     1회 이상       1회 이상        1회 이상         1회 이상
# 599998     1회 이상     1회 이상      40회 이상        1회 이상         1회 이상
#
#         이용메뉴건수_ARS_R6M  입회경과개월수_신용  _1순위카드이용건수  이용후경과월_할부_무이자
# 2                1회 이상           5         154              3
# 10               1회 이상          54           9             12
# 12              10회 이상          46         129              3
# 16               1회 이상          58         120              8
# 32               1회 이상         119          11             12
# ...                ...         ...         ...            ...
# 599957           1회 이상          17         115              4
# 599961          10회 이상         120          57             12
# 599982           1회 이상          92         101             12
# 599994          20회 이상          30          15              1
# 599998           1회 이상          82         185              2
#
# [96408 rows x 36 columns]

# %%
X_test = Xtest_df.drop(columns=['기준년월','ID'])
X_test = X_test[scaler_columns]

# %%
X_test
# Out:
#         이용금액_R3M_신용체크  _1순위카드이용금액  이용카드수_신용체크 Life_Stage  이용개월수_신용_R12M  \
# 2               40758       27071           2    자녀성장(1)             12
# 10              45764        7544           2    자녀성장(1)             11
# 12              37849       24425           2    자녀성장(2)             12
# 16              51440       42636           2      자녀출산기             12
# 32              54632        3885           2      자녀출산기             12
# ...               ...         ...         ...        ...            ...
# 599957          61148       38644           4    자녀성장(1)             12
# 599961          30318       25961           1    자녀성장(2)             12
# 599982          94440       70955           1       노년생활             12
# 599994          31697       29020           1    자녀성장(2)              9
# 599998         173263       63592           6      가족구축기             12
#
#         이용금액_일시불_R6M  이용후경과월_신판  이용건수_신용_R12M  이용후경과월_신용  이용금액_오프라인_B0M  ...  \
# 2              48483          1           650          1          11298  ...
# 10             19540          1            53          1              0  ...
# 12             46059          0           555          0          10864  ...
# 16             98761          0           565          0          13105  ...
# 32             12229          2           116          2           1006  ...
# ...              ...        ...           ...        ...            ...  ...
# 599957         74022          0           536          0          11170  ...
# 599961         67949          1           316          1          10786  ...
# 599982        129251          0           435          0          15527  ...
# 599994         20070          1            20          1           9996  ...
# 599998        133431          0           933          0          15388  ...
#
#         청구서발송여부_B0  할인건수_R3M  할인건수_B0M  방문횟수_앱_R6M  방문횟수_PC_R6M  인입횟수_ARS_R6M  \
# 2                1     1회 이상     1회 이상       1회 이상        1회 이상         1회 이상
# 10               0     1회 이상     1회 이상       1회 이상        1회 이상         1회 이상
# 12               1    10회 이상     1회 이상       1회 이상        1회 이상        10회 이상
# 16               1     1회 이상     1회 이상       1회 이상        1회 이상         1회 이상
# 32               1     1회 이상     1회 이상       1회 이상        1회 이상         1회 이상
# ...            ...       ...       ...         ...          ...           ...
# 599957           1     1회 이상     1회 이상      40회 이상       40회 이상         1회 이상
# 599961           1     1회 이상     1회 이상       1회 이상        1회 이상         1회 이상
# 599982           1     1회 이상     1회 이상       1회 이상        1회 이상         1회 이상
# 599994           1     1회 이상     1회 이상       1회 이상        1회 이상         1회 이상
# 599998           1     1회 이상     1회 이상      40회 이상        1회 이상         1회 이상
#
#         이용메뉴건수_ARS_R6M  입회경과개월수_신용  _1순위카드이용건수  이용후경과월_할부_무이자
# 2                1회 이상           5         154              3
# 10               1회 이상          54           9             12
# 12              10회 이상          46         129              3
# 16               1회 이상          58         120              8
# 32               1회 이상         119          11             12
# ...                ...         ...         ...            ...
# 599957           1회 이상          17         115              4
# 599961          10회 이상         120          57             12
# 599982           1회 이상          92         101             12
# 599994          20회 이상          30          15              1
# 599998           1회 이상          82         185              2
#
# [96408 rows x 34 columns]

# %%
X_test['할인건수_R3M'] = Encoder1.transform(X_test['할인건수_R3M'])
X_test['할인건수_B0M'] = Encoder2.transform(X_test['할인건수_B0M'])
X_test['방문횟수_앱_R6M'] = Encoder3.transform(X_test['방문횟수_앱_R6M'])
X_test['방문횟수_PC_R6M'] = Encoder4.transform(X_test['방문횟수_PC_R6M'])
X_test['인입횟수_ARS_R6M'] = Encoder5.transform(X_test['인입횟수_ARS_R6M'])
X_test['Life_Stage'] = Encoder6.transform(X_test['Life_Stage'])
X_test['이용메뉴건수_ARS_R6M'] = Encoder7.transform(X_test['이용메뉴건수_ARS_R6M'])

# %%
# 데이터 표준화
scaled_data = scalerX.transform(X_test)
scaled_data
# Out:
# array([[ 0.38005302,  0.51822497,  0.27510351, ..., -1.09326053,
#          1.62229687, -0.93006339],
#        [ 0.54351191, -0.55965122,  0.27510351, ..., -0.45081939,
#         -0.8003633 ,  0.95492744],
#        [ 0.28506662,  0.3721677 ,  0.27510351, ..., -0.55570774,
#          1.20459684, -0.93006339],
#        ...,
#        [ 2.13290962,  2.94058985, -0.60574601, ...,  0.04740027,
#          0.73677281,  0.95492744],
#        [ 0.08418785,  0.62580836, -0.60574601, ..., -0.76548444,
#         -0.70011529, -1.34895024],
#        [ 4.70668512,  2.53415761,  3.79850157, ..., -0.08371016,
#          2.14024491, -1.13950681]])

# %%
# 입력데이터를 test_X 변수에 담아준다.
X_text2 = scaled_data

# %%
# 예측한다.
y_pred = best_model.predict(X_text2)
y_pred_labels = le.inverse_transform(y_pred)
y_pred_labels
# Out:
# array(['D', 'D', 'D', ..., 'C', 'D', 'C'], dtype=object)

# %%
# 결과를 붙힌다음 저장한다.
# 예측할 데이터를 다시 불러온다.
result_df = Xtest_df
result_df['Segment'] = y_pred_labels

# %%
result_df2 = result_df[['ID', 'Segment']]

# %%
result_df2['Segment'].value_counts()
# Out:
# Segment
# D    70340
# C    26068
# Name: count, dtype: int64

# %%
most_common_by_id = result_df2.groupby('ID')['Segment'] \
    .agg(lambda x: x.mode().iloc[0]) \
    .reset_index()

# 컬럼명 확인
most_common_by_id.columns = ['ID', 'Segment']

# %%
most_common_by_id
# Out:
#                ID Segment
# 0      TEST_00002       D
# 1      TEST_00010       D
# 2      TEST_00012       D
# 3      TEST_00016       D
# 4      TEST_00032       D
# ...           ...     ...
# 16063  TEST_99957       D
# 16064  TEST_99961       D
# 16065  TEST_99982       C
# 16066  TEST_99994       D
# 16067  TEST_99998       C
#
# [16068 rows x 2 columns]

# %%
most_common_by_id['Segment'].value_counts()
# Out:
# Segment
# D    11602
# C     4466
# Name: count, dtype: int64

# %%
most_common_by_id.to_csv('data/model3_5_C,D.csv', index=False, encoding='utf-8-sig')
print('저장완료')
# Out:
# 저장완료
